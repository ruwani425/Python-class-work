# %%
print("hello")
# Out:
# hello

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
my_var=3
print(type(my_var))
# Out:
# <class 'int'>

# %%
a=8
print(type(a))
# Out:
# <class 'int'>

# %%
b="k"
print(type(b))
# Out:
# <class 'str'>

# %%
b=5.0
print(type(b))
# Out:
# <class 'float'>

# %%
m2_var=6
print(m2_var)
# Out:
# 6

# %%
a=2+3j
print(a)
# Out:
# (2+3j)

# %%
a=6.5e7
print(a)
# Out:
# 65000000.0

# %%
a=5
print(type(a))
b=float(a)
print(type(b))
print(b)
# Out:
# <class 'int'>
# <class 'float'>
# 5.0

# %%
my_list = [10,12,8,9,11]
print(my_list)
print(type(my_list))
print(my_list[2])
# Out:
# [10, 12, 8, 9, 11]
# <class 'list'>
# 8

# %%
x=5
print(id(x))
x=6
print(id(x))
# Out:
# 4386351840
# 4386351872

# %%
print(id(my_list))
my_list[2]=50
print(my_list)
print(id(my_list))
# Out:
# 4570646592
# [10, 12, 50, 9, 11]
# 4570646592

# %%
c=6.3
d=int(c)
print(d)
# Out:
# 6

# %%
print(len(my_list))
# Out:
# 5

# %%
my_list=[10,12,"cat",12.5,True]

# %%
print(my_list[1:4])
# Out:
# [12, 'cat', 12.5]

# %%
print(my_list[:4])
# Out:
# [10, 12, 'cat', 12.5]

# %%
print(my_list[2:])
# Out:
# ['cat', 12.5, True]

# %%
print(my_list[1:7:1])
# Out:
# [12, 'cat', 12.5, True]

# %%
print(my_list[-2])
# Out:
# 12.5

# %%
my_list.insert(2,77)
print(my_list)
# Out:
# [10, 12, 77, 'cat', 12.5, True]

# %%
my_list.append(22)
print(my_list)
# Out:
# [10, 12, 77, 'cat', 12.5, True, 22]

# %%
my_list[2:5]=[50,70,60]
print(my_list)
# Out:
# [10, 12, 50, 70, 60, True, 22]

# %%
my_list=["Dog","Cat","Rabbit"]
my_list.remove("Cat")
print(my_list)
# Out:
# ['Dog', 'Rabbit']

# %%
my_list=[1,2,3]
my_var=my_list.pop(1)
print(my_list)
print(my_var)
del my_list[1]
print(my_list)
# Out:
# [1, 3]
# 2
# [1]

# %%
del my_list

# %%
my_list=[1,2,3]
my_list.clear()
print(my_list)
# Out:
# []
