# %%
print("hello")
# Out:
# hello

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
my_var=3
print(type(my_var))
# Out:
# <class 'int'>

# %%
a=8
print(type(a))
# Out:
# <class 'int'>

# %%
b="k"
print(type(b))
# Out:
# <class 'str'>

# %%
b=5.0
print(type(b))
# Out:
# <class 'float'>

# %%
m2_var=6
print(m2_var)
# Out:
# 6

# %%
a=2+3j
print(a)
# Out:
# (2+3j)

# %%
a=6.5e7
print(a)
# Out:
# 65000000.0

# %%
a=5
print(type(a))
b=float(a)
print(type(b))
print(b)
# Out:
# <class 'int'>
# <class 'float'>
# 5.0

# %%
my_list = [10,12,8,9,11]
print(my_list)
print(type(my_list))
print(my_list[2])
# Out:
# [10, 12, 8, 9, 11]
# <class 'list'>
# 8

# %%
x=5
print(id(x))
x=6
print(id(x))
# Out:
# 4355713760
# 4355713792

# %%
print(id(my_list))
my_list[2]=50
print(my_list)
print(id(my_list))
# Out:
# 4405392832
# [10, 12, 50, 9, 11]
# 4405392832

# %%
c=6.3
d=int(c)
print(d)
# Out:
# 6

# %%
print(len(my_list))
# Out:
# 5

# %%
my_list=[10,12,"cat",12.5,True]

# %%
print(my_list[1:4])
# Out:
# [12, 'cat', 12.5]

# %%
print(my_list[:4])
# Out:
# [10, 12, 'cat', 12.5]

# %%
print(my_list[2:])
# Out:
# ['cat', 12.5, True]

# %%
print(my_list[1:7:1])
# Out:
# [12, 'cat', 12.5, True]

# %%
print(my_list[-2])
# Out:
# 12.5

# %%
my_list.insert(2,77)
print(my_list)
# Out:
# [10, 12, 77, 'cat', 12.5, True]

# %%
my_list.append(22)
print(my_list)
# Out:
# [10, 12, 77, 'cat', 12.5, True, 22]

# %%
my_list[2:5]=[50,70,60]
print(my_list)
# Out:
# [10, 12, 50, 70, 60, True, 22]

# %%
my_list=["Dog","Cat","Rabbit"]
my_list.remove("Cat")
print(my_list)
# Out:
# ['Dog', 'Rabbit']

# %%
my_list=[1,2,3]
my_var=my_list.pop(1)
print(my_list)
print(my_var)
del my_list[1]
print(my_list)
# Out:
# [1, 3]
# 2
# [1]

# %%
del my_list

# %%
my_list=[1,2,3]
my_list.clear()
print(my_list)
# Out:
# []

# %%
sports = ("tennis","cricket","football","football")
print(sports)
print(type(sports))
print(sports[1])
# Out:
# ('tennis', 'cricket', 'football', 'football')
# <class 'tuple'>
# cricket

# %%
# sports[1]="baseball"

# %%
sports=("tennis")
print(type(sports))
sports=("tennis",)
print(type(sports))
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
sports = ("tennis","cricket","football","football")
print(sports[-1])
# Out:
# football

# %%
sports = ("tennis","cricket","football","football")
print(sports[1:3])
# Out:
# ('cricket', 'football')

# %%
sports = ("tennis","cricket","football","football")
x=list(sports)
print(x,type(x))
x[1]="baseball"
sports=tuple(x)
# Out:
# ['tennis', 'cricket', 'football', 'football'] <class 'list'>

# %%
nested_tuple = ((1,2,3),(a,b,c),(True,False))

# %%
sports = {"tennis","cricket","football"}
print(sports)
print(type(sports))
print(sports[2])
# Out:
# {'cricket', 'football', 'tennis'}
# <class 'set'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[330], line 4
#       2 print(sports)
#       3 print(type(sports))
# ----> 4 print(sports[2])
#
# TypeError: 'set' object is not subscriptable

# %%
sports = {"tennis","tennis","football"}
print(sports)
# Out:
# {'football', 'tennis'}

# %%
sports.add("soccer")
print(sports)
sports.add("vollyball")
print(sports)
# Out:
# {'soccer', 'vollyball', 'football', 'tennis'}
# {'soccer', 'vollyball', 'football', 'tennis'}

# %%
sports = {"tennis","cricket","football"}
sports.update(["sport1","sport2"])
print(sports)
# Out:
# {'sport1', 'sport2', 'cricket', 'tennis', 'football'}

# %%
sports.remove("tennis")
print(sports)
# Out:
# {'sport1', 'sport2', 'cricket', 'football'}

# %%
my_var = range(1,17,3)
print(my_var)
# Out:
# range(1, 17, 3)

# %%
print(my_var[0])
print(my_var[1])
print(my_var[2])
print(my_var[3])
print(my_var[4])
print(my_var[5])
# Out:
# 1
# 4
# 7
# 10
# 13
# 16

# %%
my_var=range(13)
print(my_var[0])
print(my_var[1])
print(my_var[2])
print(my_var[3])
print(my_var[4])
print(my_var[5])
print(my_var[12])
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 12

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00
}
print(item_1)
print(type(item_1))
# Out:
# {'name': 'sugar', 'weight': '1kg', 'price': 175.0}
# <class 'dict'>

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00
}
print(item_1["name"])
print(item_1["price"])
print(item_1["weight"])
# Out:
# sugar
# 175.0
# 1kg

# %%
item_1["price"]=180.00
print(item_1)
# Out:
# {'name': 'sugar', 'weight': '1kg', 'price': 180.0}

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00,
    "price":150.00
}
print(item_1)
# Out:
# {'name': 'sugar', 'weight': '1kg', 'price': 150.0}

# %%
print(len(item_1))
# Out:
# 3

# %%
this_dict = {
    "name":"sugar",
    "weight":"1kg",
}
print(this_dict.get("price",50.00))
# Out:
# 50.0

# %%
this_dict["expiry_date"]="28/05/2027"
print(this_dict)
# Out:
# {'name': 'sugar', 'weight': '1kg', 'expiry_date': '28/05/2027'}

# %%
this_dict.update({"weight":"2kg","price":120})
print(this_dict)
# Out:
# {'name': 'sugar', 'weight': '2kg', 'expiry_date': '28/05/2027', 'price': 120}

# %%
x = 5
y = 4
print(x**y)
#5 hi 4 wana balaya
# Out:
# 625

# %%
y // x
#y,x gen bedu wita ena eke purna sankyawa
# Out:
# 0

# %%
y % x
# Out:
# 4

# %%
x = 5
print(x)
x += 2
print(x)
# Out:
# 5
# 7

# %%
x = 5
print(x)

x -= 3
print(x)
# Out:
# 5
# 2

# %%
x=16
x %= 5
print(x)
# Out:
# 1

# %%
x=10
x **= 2
print(x)
# Out:
# 100

# %%
x=10
x //= 2
print(x)
# Out:
# 5

# %%
x==y
# Out:
# False

# %%
product_ids=[101,102,103,104,105,106,107,108,109]
new_pro_ids=set(product_ids)
has_duplicates = len(product_ids) > len(new_pro_ids)
print(has_duplicates)
# Out:
# False

# %%
x=3
y=3
print(x is y)
# Out:
# True

# %%
x=77777777777
y=99999999999
print(x is y)
# Out:
# False

# %%
nums = [1,2,3,6,4]
print(8 in nums)
# Out:
# False

# %%
f=3
print(id(f))
f=4
print(id(f))
# Out:
# 4399344288
# 4399344320
