# %%
sports = ("tennis","cricket","football","football")
print(sports)
print(type(sports))
print(sports[1])

# %%
sports[1]="baseball"

# %%
sports=("tennis")
print(type(sports))
sports=("tennis",)
print(type(sports))

# %%
sports = ("tennis","cricket","football","football")
print(sports[-1])

# %%
sports = ("tennis","cricket","football","football")
print(sports[1:3])

# %%
sports = ("tennis","cricket","football","football")
x=list(sports)
print(x,type(x))
x[1]="baseball"
sports=tuple(x)

# %%
nested_tuple = ((1,2,3),(a,b,c),(True,False))

# %%
sports = {"tennis","cricket","football"}
print(sports)
print(type(sports))
print(sports[2])

# %%
sports = {"tennis","tennis","football"}
print(sports)

# %%
sports.add("soccer")
print(sports)
sports.add("vollyball")
print(sports)

# %%
sports = {"tennis","cricket","football"}
sports.update(["sport1","sport2"])
print(sports)

# %%
sports.remove("tennis")
print(sports)

# %%
my_var = range(1,17,3)
print(my_var)

# %%
print(my_var[0])
print(my_var[1])
print(my_var[2])
print(my_var[3])
print(my_var[4])
print(my_var[5])

# %%
my_var=range(13)
print(my_var[0])
print(my_var[1])
print(my_var[2])
print(my_var[3])
print(my_var[4])
print(my_var[5])
print(my_var[12])

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00
}
print(item_1)
print(type(item_1))

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00
}
print(item_1["name"])
print(item_1["price"])
print(item_1["weight"])

# %%
item_1["price"]=180.00
print(item_1)

# %%
item_1 = {
    "name" : "sugar",
    "weight":"1kg",
    "price":175.00,
    "price":150.00
}
print(item_1)

# %%
print(len(item_1))

# %%
this_dict = {
    "name":"sugar",
    "weight":"1kg",
}
print(this_dict.get("price",50.00))

# %%
this_dict["expiry_date"]="28/05/2027"
print(this_dict)

# %%
this_dict.update({"weight":"2kg","price":120})
print(this_dict)
