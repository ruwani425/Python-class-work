# %%
a = 5
b = 5
number = sum(a,b)
#python function
def sum(a,b) :
    return a+b
print(number)

# %%
def square_sum (n) :
    sum = 0
    for item in range(1,n + 1) :
       sum += item ** 2
    return sum
print(square_sum(3))

# %%
list_1 = [1,2,3]
list_2 = [2,3,4]
def add_corresponding_numbers(list_1,list_2) :
    if len(list_1) != len(list_2) :
        return "Error: Lists should be in equal lenght"
    else:
        sum_list = []
        for item in range(len(list_1)) :
            sum_list.append(list_1[item] + list_2[item])
        return sum_list
print(add_corresponding_numbers(list_1,list_2))

# %%
def add(a,b=10) :
    return a+b
print(add(1,3))

# %%
def calculate_total(price,quantity = 1,discount = 0) :
    total_cost = price*quantity
    discount_percentage = total_cost * discount/100
    total_cost -= total_cost * discount/100
    return "Total cost = ",total_cost,"Discount percentage =",discount_percentage


print(calculate_total(100,2,2))
print(calculate_total(1))
print(calculate_total(1,2))

# %%
def add(b,a) :
    return a,b
print(add(a = 2,b = 3))

# %%
def sum_numbers(*args) :
    total = 0
    for i in args :
        total += i
    return total
print(sum_numbers(1,2,4))

# %%
def average_positive(*args) :
    total = 0
    average = 0
    count = 0
    for i in args :
        if i > 0 :
            total += i
            count += 1
            average = total/count
    return average if count > 0  else "No positive numbers prived"
print(average_positive(-3,1,2))

# %%
def arbitrary_keyword_args(**kwargs) :
    print(kwargs)
    print(type(kwargs))
arbitrary_keyword_args(name = "ruwani",city ="colombo",age = 24)

# %%
def arbitrary_keyword_args(**kwargs) :
    # print(kwargs)
    # print(type(kwargs))

    #1st option
    # for i in kwargs :
    #     print(i,kwargs[i])


    #2nd option
    # for key in kwargs.keys() :
    #     print(key)
    # for value in kwargs.values() :
    #     print(value)

    #3rd option
    for key,value in kwargs.items() :
        print(key,":",value)
arbitrary_keyword_args(name = "ruwani",city ="colombo",age = 24)

# %%
def average_score(**kwargs):
    total = 0
    count = 0
    for i in kwargs.values():
        total += i
        count += 1
    if count > 0:
        return total / count
    else:
        return "no subjects are provided"

print(average_score())                   
print(average_score(math=80, english=90))

# %%
def absolute_value(number) :
    if number < 0 :
       number = number * -1
       return number
    return number
print(absolute_value(-10))

# %%
print(abs(-10))
#built in function

# %%
def find_square (x) :
    return x ** 2
list_1 = [6,3,4,5]
result = map(find_square,list_1)
print(type(result))
print(result)
print(list(result))

# %%
def convert_to_celsius (tempreture) :
    celsius = (tempreture - 32) * 5/9
    return round(celsius,2)
list_1 = [32,25,77]
result = map(convert_to_celsius,list_1)
print(type(result))
print(list(result))

# %%
list_1 = [1,2,4,5]
list_2 = [3,4,5,6]
list_3 = [3,4,5,5]
def add_corresponding_numbers(num_1,num_2,num_3) :
   return num_1 + num_2 + num_3
result = map(add_corresponding_numbers,list_1,list_2,list_3)
#can pass multiple arguments
print(result)
print(list(result))

# %%
def is_even(number) :
    if number%2 == 0 :
        return True
    
list_1 = [10,9,4,8,11]
result = filter(is_even,list_1)
print(list(result))
# Out:
# [10, 4, 8]

# %%
def check_num(number) :
    if number % 3 == 0 and number % 5 != 0 :
        return True
list_1 = [12,15,18,20,25,30,35]
result = filter(check_num,list_1)
print(list(result))

# %%
#option 1
add = lambda x,y : x + y
print(add(3,4))
# Out:
# 7

# %%
#option 2
result = (lambda x,y : x + y)(3,4)
print(result)
# Out:
# 7

# %%
maximum = lambda x,y : x if x > y else y
print(maximum(4,3))

# %%
square = lambda number : number ** 2
list_1 = [1,3,4,5]
print(list(map(square,list_1)))

# %%
check_number = lambda number : number % 3 == 0 and number % 5 != 0
list_1 = [3,5,15,20,6]
print(list(filter(check_number,list_1)))
