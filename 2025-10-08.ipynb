# %%
a = 5
b = 10

if a > b:
    print("a is greater than b")
else:
    print("a is not grater than b")
print("This is outside of the block")
#if is identify this space(identation)
#we can use if only
#and we can use if else both
#3rd print statement is out side of the if else
# Out:
# a is not grater than b
# This is outside of the block

# %%
num = input("enter a number")
if int(num) % 2 == 0:
    print("it is a even number")
else:
    print("it is a odd number")
    
#can use int(input("enter a number"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 num = input("enter a number")
#       2 if int(num) % 2 == 0:
#       3     print("it is a even number")
#
# File ~/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
# ...

# %%
radious = float(input("enter the radious"))
PI_VALUE = 3.14
if 0 < radious:
    circumference = 2 * PI_VALUE * radious
    print(circumference)
else:
    print("input is less than 0,it must be grater than 0")
# Out:
# 31.400000000000002

# %%
height = float(input("enter height"))
width = float(input("input width"))
if 0 < height and 0 < width :
    hypotenuse = (height ** 2 + width ** 2) ** 0.5
    print("hypotenuse is ",hypotenuse)
# Out:
# hypotenuse is  5.656854249492381

# %%
a = 15 
if a > 0 :
    print("positive number")
elif a < 0 :
    print("negative number")
else :
    print("number is zero")

#elif mean else-if
# Out:
# positive number

# %%
a = 4
b = 5
c = 7

if a > b and a > c :
    print("a is a large number")
elif b > a and b > c :
    print("b is a large number")
else :
    print("c is a large number")
# Out:
# c is a large number

# %%
number_1 = float(input("enter number 1"))
number_2 = float(input("enter number 2"))
number_3 = float(input("enter number 3"))

if number_1 >= number_2 and number_1 >= number_3 :
    first_value = number_1
    if number_2 <= number_3 :
        last_value = number_2
        mid_value = number_3
    elif number_3 <= number_2 :
        last_value = number_3
        mid_value = number_2
elif number_2 >= number_1 and number_2 >= number_3 :
    first_value = number_2
    if number_1 <= number_3 :
        last_value = number_1
        mid_value = number_3
    elif number_3 <= number_1 :
        last_value = number_3
        mid_value = number_1
elif number_3 >= number_1 and number_3 >= number_2 :
    first_value = number_3
    if number_1 <= number_2 :
        last_value = number_1
        mid_value = number_2
    elif number_2 <= number_1 :
        last_value = number_2
        mid_value = number_1

print (first_value,mid_value,last_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 number_1 = float(input("enter number 1"))
#       2 number_2 = float(input("enter number 2"))
#       3 number_3 = float(input("enter number 3"))
#
# ValueError: could not convert string to float: ''

# %%
x = 10
result = "Even" if x % 2 == 0 else "odd"
print(result)
#ternary operator
# Out:
# Even

# %%
number = float(input("enter number"))
result = number * -1 if number < 0 else number
print(result)
# Out:
# 0.0

# %%
x = 2
match x :
    case 1 :
        print("x is 1")
    case 2 :
        print("x is 2")
    case 3 :
        print("x is 3")
    case _:
        print("x is something else")
# Out:
# x is 2

# %%
day = input("enter the day")
match day :
    case "monday" | "tuesday" | "wednsday" | "thursday" | "friday" :
        print("it is a weekday")
    case _:
        print("it is a weekend day")
# Out:
# it is a weekend day

# %%
numbers = [4,3,7]
match numbers:
    case[x, y]:
        print(x*y)
    case[x,y,z]:
        print(x*y*z)
    case _:
        print("The list does not contain 2 or 3 numbers")
# Out:
# 84

# %%
numbers = [2,4,5]
match numbers:
    case [x,y]:
        hypotenuse = (x ** 2 + y ** 2) ** 0.5
        print("hypotenuse :",hypotenuse)
    case [x,y,z]:
        s = (x+y+z)/2
        area = (s*(s-x)*(s-y)*(s-c)) ** 0.5
        print("area :",area)
    case _:
        print("invalid")
# Out:
# area : 12.60208316112856

# %%
num = [9,3,4,7,3]
for item in num :
    print(item)
# Out:
# 9
# 3
# 4
# 7
# 3

# %%
for item in range(7,100,7) :
    print(item)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98

# %%
num = int(input("Enter number :"))
factorial=1
if num < 0:
    print("negative number")
else :
    for item in range(1,(num+1)) :
        factorial *= item
    print(factorial)
# Out:
# 120

# %%
num = 6
for item in range(1,num + 1):
    print("* " * item)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
count = 10
sum = 0
for item in range(1,count+1):
    num = int(input("Enter number "))
    if num != 0:
        sum += num
    else:
        break
print(sum)
# Out:
# 20
